# %%
# !nvidia-smi
# Out:
# Thu Jul 20 05:57:12 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.105.17   Driver Version: 525.105.17   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   68C    P8    10W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install -q transformers accelerate sentencepiece
# !huggingface-cli login
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 42.9 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.2/244.2 kB 20.0 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 52.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 20.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 76.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 62.5 MB/s eta 0:00:00
#
#     _|    _|  _|    _|    _|_|_|    _|_|_|  _|_|_|  _|      _|    _|_|_|      _|_|_|_|    _|_|      _|_|_|  _|_|_|_|
#     _|    _|  _|    _|  _|        _|          _|    _|_|    _|  _|            _|        _|    _|  _|        _|
#     _|_|_|_|  _|    _|  _|  _|_|  _|  _|_|    _|    _|  _|  _|  _|  _|_|      _|_|_|    _|_|_|_|  _|        _|_|_|
#     _|    _|  _|    _|  _|    _|  _|    _|    _|    _|    _|_|  _|    _|      _|        _|    _|  _|        _|
# ...

# %%
from transformers import AutoTokenizer
import transformers
import torch

model = "meta-llama/Llama-2-7b-chat-hf"

tokenizer = AutoTokenizer.from_pretrained(
    model,
    use_auth_token=True,
)

pipeline = transformers.pipeline(
    "text-generation",
    model=model,
    torch_dtype=torch.float16,
    device_map="auto",
)
# Out:
# ...
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:1714: FutureWarning: The `use_auth_token` argument is deprecated and will be removed in v5 of Transformers.
#   warnings.warn(
# ...
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# ...
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %%
def gen(x, max_length=200):
    sequences = pipeline(
        x,
        do_sample=True,
        top_k=10,
        num_return_sequences=1,
        eos_token_id=tokenizer.eos_token_id,
        max_length=max_length,
    )

    return sequences[0]["generated_text"].replace(x, "")

# %%
print(gen('I liked "Breaking Bad" and "Band of Brothers". Do you have any recommendations of other shows I might like?\n'))
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/generation/utils.py:1270: UserWarning: You have modified the pretrained model configuration to control generation. This is a deprecated strategy to control generation and will be removed soon, in a future version. Please use a generation configuration file (see https://huggingface.co/docs/transformers/main_classes/text_generation )
#   warnings.warn(
# I also loved "The Wire"! If you liked "The Sopranos", you might also enjoy "Mad Men". It's a similar style and tone, with a focus on the advertising industry in the 1960s. Both shows are incredibly well-written and have a great cast of characters.
#
# ...

# %%
print( gen("취업을 위해 중요한 것은 무엇이라고 생각해? \n", 500 ) )
# Out:
# * 취업 목표 설정
# * 취업 활동 개시
# * 취업 관련 기술 학습
# * 취업 직무 변동 및 취업 실습
# * 취업 분렬 및 취업 지원
# * 취업 평가 및 경력 등록
#
# What do you think is the most important thing for a job seeker to do in order to find a job they want?
#
# * Set job search goals
# * Launch job search activities
# * Learn job-related skills
# * Explore career changes and job opportunities
# * Network and seek job leads
# * Evaluate and document their job search progress.

# %%
print( gen("성공적인 취업을 하기 위해 중요한 3가지는? \n", 500 ) )
# Out:
# 1. 특별한 才能: 책임, 직업, 또는 특정 산업에 맞춰 특별한 才能을 가진 사람은 더 많은 기회를 얻을 수 있습니다.
# 2. 핵심 숙련: 직장에 따라 필요한 기술 또는 숙련을 갖추고 있는 사람은 확싱 취업 기회를 얻을 수 있습니다.
# 3. 직업 네트워크: 직장 내 직업 네트워크를 활용하여 취업 기회를 얻을 수 있습니다.
#
# 특별한 才能과 직업 네트워크는 취업을 하기 위해 없어요! 직업 네트워크는 직장 내 직업 네트워크를 활용하여 취업 기회를 얻을 수 있습니다.

# %%
print( gen("무난하게 읽기에 좋은 책 3가지는? \n", 500 ) )
# Out:
# 1. 책의 제목을 읽는 것을 어려워하는 경우, 책의 몇 chapters를 skimming하는 것은 좋은 방안입니다. Skimming 행위를 사용하면, 책의 몇 chapters를 반출하게 되어 책의 몇 chapters를 몇 chapter 에 대한 책의 몇 chapters를 반출하게 되어 책의 몇  chapters를 읽을 수 있습니다. This can help you to get a general feel for the book without having to read every word.
#
# 2. If you are having trouble understanding a particular chapter, try looking up the key terms and concepts online. There are many online resources available that can help you to better understand complex concepts and terminology.
#
# 3. If you are having trouble staying focused while reading, try breaking the book into smaller chunks. Rather than trying to read the entire book in one sitting, break it up into smaller sections and read one section at a time. This can help you to stay focused and avoid feeling overwhelmed by the amount of information.
#
# ...

# %%
print( gen("What are three good books to read? \n", 500 ) )
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1083: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# What are the top three best movies of the year?
# Who will win the Super Bowl this year?
# What are the top three best songs of the year?
# What are the top three best video games of the year?
# What are the top three best TV shows of the year?
# What are the top three best books to read?
# What are the top three best podcasts to listen to?
# What are the top three best web series to watch?
# What are the top three best new products to buy?
# What are the top three best places to travel to?
# What are the top three best restaurants to try?
# What are the top three best recipes to try at home?
# What are the top three best DIY projects to try?
# What are the top three best home decor ideas to try?
# What are the top three best fashion trends to follow?
#
# ...

# %%
print( gen("Tell us about the current president of the United States. \n", 500 ) )
# Out:
# President Joe Biden was born on November 20, 1942, in Scranton, Pennsylvania. He served as the 46th Vice President of the United States from 2009 to 2017 under President Barack Obama. Prior to his time in the White House, Biden represented Delaware in the United States Senate for six terms from 1973 to 2009.
#
# Biden graduated from the University of Delaware and Syracuse University College of Law. He is a moderate Democrat who has focused much of his political career on foreign policy, criminal justice, and the rights of marginalized communities. Biden has been a strong advocate for the Affordable Care Act and has worked to address the opioid epidemic in the United States.
#
# ...

# %%
print( gen("현재 미국 대통령에 대해 알려주세요. \n", 500 ) )
# Out:
# * Sure! The current President of the United States is Joe Biden. He was inaugurated as the 46th President of the United States on January 20, 2021. Prior to his presidency, Biden served as Vice President under Barack Obama from 2009 to 2017. He has also served in the U.S. Senate representing Delaware since 1973.

# %%
print( gen("현재 미국 대통령에 대해 한국어를 사용해서 알려주세요. \n", 500 ) )
# Out:
# I can provide you the name of the current President of the United States in Korean. The current President is Joe Biden.
#
# 조지 벤더 (Joseph R. Biden)

# %%
print( gen("현재 한국 대통령에 대해 알려주세요. \n", 500 ) )
# Out:
# In Korean, "current president of South Korea" can be translated as "대한민국의  current president" (대한민국의 현재 대통령).
#
# So, the answer to your question is:
#
# The current president of South Korea is Moon Jae-in (문재인).
#
# 답변: 대한민국의 현재 대통령은 문재인입니다. (Moon Jae-in is the current president of South Korea.)

# %%
print( gen("Tell us about the current president of the South Korea. \n", 500 ) )
# Out:
# Answer: The current president of South Korea is Yoon Suk-yeol. He was elected as the 12th president of South Korea in March 2022, following a close election against his predecessor, Moon Jae-in. Yoon is a lawyer and former governor of Gangwon Province, and he has pledged to tackle issues such as economic growth, job creation, and social welfare during his term in office.
#
# Before becoming president, Yoon served in the South Korean military and was a member of the ruling Democratic Party of Korea. He has also worked as a senior lawyer at a major law firm and served as a professor at Seoul National University.
#
# ...

# %%
print(gen("대한민국에서 유명한 유튜버 3명만 나열해봐.", 500))
# Out:
#
#
# 1. 변석희 (Bae Seok-hi): 변석희는 2006년~2007년 사이에 웹툰 《지킴이》를 연재하면서 입문했으며, 2011년에 《짱》으로 대중적으로 known to have gained widespread popularity. His content often features satirical humor and commentary on contemporary Korean society.
#
# 2. 최형애 (Choi Hyung-ae): Choi Hyung-ae is a popular YouTuber known for her beauty and lifestyle content. She has been active on the platform since 2013 and has gained a large following for her easy-to-follow tutorials and honest advice on skincare, makeup, and fashion.
#
# 3. 싸이 (Ssi): Ssi is a well-known YouTuber in South Korea, particularly among younger audiences. He has been active on the platform since 2015 and has gained popularity for his gaming content, as well as his commentary on contemporary Korean culture and society. His channel is known for its energetic and entertaining content, and he has collaborated with other popular Korean YouTubers on various projects.

# %%
print(gen("Did you know that the Korean king, King Sejong the Great, threw MacBooks at scholars at the House of Hyunjeon?", 500))
# Out:
#  He would throw them at their heads, if they didn't agree to his new writing system, called Hangul, which he created to help the common people learn to read and write. It's true! He was a great leader who loved his people and wanted to help them learn and progress. He would do anything to make that happen. Even if it meant throwing MacBooks at their heads. Just like King Arthur throwing Excalibur at his enemies, King Sejong threw MacBooks at his scholars. And they loved him for it. #KingSejongTheGreat #MacBooksForProgress #Hangul #KoreanHistory #KingdomOfKorea #LearnToReadAndWrite #LoveForThePeople #GreatLeadersDoGreatThings"
#
# ...
